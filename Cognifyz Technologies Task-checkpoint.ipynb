# %% [markdown]
# # Cognifyz Technologies Task

# %% [markdown]
# # 1. Know Your Data

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from plotly.offline import iplot
import plotly as py
import plotly.tools as tls
import cufflinks as cf
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load Dataset

# %%
df = pd.read_csv(r'C:\Users\Sony\Downloads\Cognifyz_Technologies_Task\Dataset .csv', encoding='ISO-8859-1')

# %% [markdown]
# # Dataset First View

# %%
df.head()
# Out:
#    ï»¿Restaurant ID         Restaurant Name  Country Code              City  \
# 0           6317637        Le Petit Souffle           162       Makati City
# 1           6304287        Izakaya Kikufuji           162       Makati City
# 2           6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                    Ooma           162  Mandaluyong City
# 4           6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# 3      SM Megamall, Ortigas, Mandaluyong City
# 4      SM Megamall, Ortigas, Mandaluyong City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City, Ma...  121.056831  14.581404
# 3  SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.056475  14.585318
# 4  SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.057508  14.584450
#
#                            Cuisines  ...          Currency Has Table booking  \
# 0        French, Japanese, Desserts  ...  Botswana Pula(P)               Yes
# 1                          Japanese  ...  Botswana Pula(P)               Yes
# 2  Seafood, Asian, Filipino, Indian  ...  Botswana Pula(P)               Yes
# 3                   Japanese, Sushi  ...  Botswana Pula(P)                No
# 4                  Japanese, Korean  ...  Botswana Pula(P)               Yes
#
#   Has Online delivery Is delivering now Switch to order menu Price range  \
# 0                  No                No                   No           3
# 1                  No                No                   No           3
# 2                  No                No                   No           4
# 3                  No                No                   No           4
# 4                  No                No                   No           4
#
#    Aggregate rating  Rating color Rating text Votes
# 0               4.8    Dark Green   Excellent   314
# 1               4.5    Dark Green   Excellent   591
# 2               4.4         Green   Very Good   270
# 3               4.9    Dark Green   Excellent   365
# 4               4.8    Dark Green   Excellent   229
#
# [5 rows x 21 columns]

# %% [markdown]
# # Dataset Rows & Columns count

# %%
rows, cols = df.shape
print(f'There are {rows} rows and {cols} columns in the dataset.')
# Out:
# There are 9551 rows and 21 columns in the dataset.

# %% [markdown]
# # Duplicate Values

# %%
duplicate_rows = df.duplicated().sum()
print(f'There are {duplicate_rows} duplicate_rows in the dataset')
# Out:
# There are 0 duplicate_rows in the dataset

# %% [markdown]
# # Missing Values/Null Values

# %%
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# ï»¿Restaurant ID        0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
null_values = df.isna()
null_columns = null_values.any()

null_columns = df.columns[null_columns].tolist()
print(null_columns)
# Out:
# ['Cuisines']

# %% [markdown]
# # Visualizing the missing values

# %%
# Visualizing the missing values
import missingno as msno

#Visualise the missing values as a matrix
msno.matrix(df)
# Out:
# <Axes: >

# %% [markdown]
# # 2. Understanding Your Variables

# %%
columns = df.columns
print('"Columns in the dataset"')
for column in columns:
    print(column)
# Out:
# "Columns in the dataset"
# ï»¿Restaurant ID
# Restaurant Name
# Country Code
# City
# Address
# Locality
# Locality Verbose
# Longitude
# Latitude
# Cuisines
# Average Cost for two
# Currency
# Has Table booking
# Has Online delivery
# Is delivering now
# Switch to order menu
# Price range
# Aggregate rating
# Rating color
# Rating text
# Votes

# %% [markdown]
# # Dataset Describe

# %%
summary = df.describe()
print(summary)
# Out:
#        ï»¿Restaurant ID  Country Code    Longitude     Latitude  \
# count      9.551000e+03   9551.000000  9551.000000  9551.000000
# mean       9.051128e+06     18.365616    64.126574    25.854381
# std        8.791521e+06     56.750546    41.467058    11.007935
# min        5.300000e+01      1.000000  -157.948486   -41.330428
# 25%        3.019625e+05      1.000000    77.081343    28.478713
# 50%        6.004089e+06      1.000000    77.191964    28.570469
# 75%        1.835229e+07      1.000000    77.282006    28.642758
# max        1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# 25%              250.000000     1.000000          2.500000      5.000000
# 50%              400.000000     2.000000          3.200000     31.000000
# 75%              700.000000     2.000000          3.700000    131.000000
# max           800000.000000     4.000000          4.900000  10934.000000

# %% [markdown]
# # 3. Data Wrangling

# %%
print(df.isnull().sum())
# Out:
# ï»¿Restaurant ID        0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
pd.set_option('display.max_rows', None)
print(df.dtypes)
# Out:
# ï»¿Restaurant ID          int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# dtype: object

# %%
pd.reset_option('display.max_rows')

# %%
df.rename(columns={'ï»¿Restaurant ID':'Restaurant ID'},inplace=True)

# %%
df.head(5)
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# 3      SM Megamall, Ortigas, Mandaluyong City
# 4      SM Megamall, Ortigas, Mandaluyong City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City, Ma...  121.056831  14.581404
# 3  SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.056475  14.585318
# 4  SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.057508  14.584450
#
#                            Cuisines  ...          Currency Has Table booking  \
# 0        French, Japanese, Desserts  ...  Botswana Pula(P)               Yes
# 1                          Japanese  ...  Botswana Pula(P)               Yes
# 2  Seafood, Asian, Filipino, Indian  ...  Botswana Pula(P)               Yes
# 3                   Japanese, Sushi  ...  Botswana Pula(P)                No
# 4                  Japanese, Korean  ...  Botswana Pula(P)               Yes
#
#   Has Online delivery Is delivering now Switch to order menu Price range  \
# 0                  No                No                   No           3
# 1                  No                No                   No           3
# 2                  No                No                   No           4
# 3                  No                No                   No           4
# 4                  No                No                   No           4
#
#    Aggregate rating  Rating color Rating text Votes
# 0               4.8    Dark Green   Excellent   314
# 1               4.5    Dark Green   Excellent   591
# 2               4.4         Green   Very Good   270
# 3               4.9    Dark Green   Excellent   365
# 4               4.8    Dark Green   Excellent   229
#
# [5 rows x 21 columns]

# %% [markdown]
# # 4. Data Vizualization

# %% [markdown]
# # Level 1 - Task 1 : "Top Cuisines"

# %% [markdown]
# # Determine the top three most common cuisines in the dataset.

# %% [markdown]
# # Calculate the percentage of restaurants that serve each of the top cuisines.

# %%
#Determine the top three most common cuisines in the dataset.
top_cuisines = df['Cuisines'].value_counts().nlargest(3).index.tolist()
print("Top Three Cuisines:")
for index, Cuisines in enumerate(top_cuisines, 1):
    print(f"{index}. {Cuisines}")

#Calculate the percentage of restaurants that serve each of the top cuisines.
percentage_cuisine = (df['Cuisines'].value_counts(normalize=True) * 100).loc[top_cuisines]
print("\nPercentage of Restaurants Serving Each Top Cuisine:")
for Cuisines, percentage in percentage_cuisine.iteritems():
    print(f"- {Cuisines}: {percentage:.2f}%")
# Out:
# Top Three Cuisines:
# 1. North Indian
# 2. North Indian, Chinese
# 3. Chinese
#
# Percentage of Restaurants Serving Each Top Cuisine:
# - North Indian: 9.81%
# - North Indian, Chinese: 5.36%
# - Chinese: 3.71%

# %% [markdown]
# # Level 1 - Task 2 : "City Analysis"

# %% [markdown]
# # Identify the city with the highest number of restaurants in the dataset.

# %% [markdown]
# # Calculate the average rating for restaurants in each city.

# %% [markdown]
# # Determine the city with the highest average rating.

# %%
# Identify the city with the highest number of restaurants
top_city_restaurants = df['City'].value_counts().idxmax()
print(f"The city with the highest number of restaurants is: {top_city_restaurants}")

# Calculate the average rating for restaurants in each city
average_rating_per_city = df.groupby('City')['Aggregate rating'].mean()

# Determine the city with the highest average rating
city_highest_avg_rating = average_rating_per_city.idxmax()
highest_avg_rating = average_rating_per_city.max()

print(f"\nThe city with the highest average rating is: {city_highest_avg_rating}")
print(f"\nThe average rating in that city is: {highest_avg_rating:.2f}")
# Out:
# The city with the highest number of restaurants is: New Delhi
#
# The city with the highest average rating is: Inner City
#
# The average rating in that city is: 4.90

# %% [markdown]
# # Level 1 - Task 3 : "Price Range Distribution"

# %% [markdown]
# # Create a histogram or bar chart to visualize the distribution of price ranges among the restaurants.

# %% [markdown]
# # Calculate the percentage of restaurants in each price range category.

# %%
# Plotting the histogram or bar chart for price ranges
colors = ['skyblue', 'lightgreen', 'lightcoral', 'orange']
plt.figure(figsize=(10, 6))
df['Price range'].value_counts().sort_index().plot(kind='bar', color=colors)
plt.title('Price Range Distribution Among Restaurants')
plt.xlabel('Price Range')
plt.ylabel('Number of Restaurants')
plt.xticks(rotation=0)
plt.show()

# Calculate the percentage of restaurants in each price range category
price_range_percentage = (df['Price range'].value_counts(normalize=True) * 100).sort_index()
print("\nPercentage of Restaurants in Each Price Range Category:")
for price_range, percentage in price_range_percentage.iteritems():
    print(f"- Price Range {price_range}: {percentage:.2f}%")
# Out:
# Percentage of Restaurants in Each Price Range Category:
# - Price Range 1: 46.53%
# - Price Range 2: 32.59%
# - Price Range 3: 14.74%
# - Price Range 4: 6.14%

# %% [markdown]
# # Level 1 - Task 4 : "Online Delivery"

# %% [markdown]
# # Determine the percentage of restaurants that offer online delivery.

# %% [markdown]
# # Compare the average ratings of restaurants with and without online delivery.

# %%
# Determine the percentage of restaurants that offer online delivery
online_delivery_percentage = (df['Has Online delivery'].value_counts(normalize=True) * 100).get('Yes', 0)
print(f"Percentage of Restaurants Offering Online Delivery: {online_delivery_percentage:.2f}%")

# Task 2: Compare the average ratings of restaurants with and without online delivery
average_rating_with_delivery = df[df['Has Online delivery'] == 'Yes']['Aggregate rating'].mean()
average_rating_without_delivery = df[df['Has Online delivery'] == 'No']['Aggregate rating'].mean()

print(f"\nAverage Rating of Restaurants with Online Delivery: {average_rating_with_delivery:.2f}")
print(f"\nAverage Rating of Restaurants without Online Delivery: {average_rating_without_delivery:.2f}")
# Out:
# Percentage of Restaurants Offering Online Delivery: 25.66%
#
# Average Rating of Restaurants with Online Delivery: 3.25
#
# Average Rating of Restaurants without Online Delivery: 2.47

# %% [markdown]
# # Level 2 - Task 1 : "Restaurant Ratings"

# %% [markdown]
# # Analyze the distribution of aggregate ratings and determine the most common rating range.

# %% [markdown]
# # Calculate the average number of votes received by restaurants.

# %%
# Analyze the distribution of aggregate ratings and determine the most common rating range
rating_counts = df['Aggregate rating'].value_counts().sort_index(ascending=False)
most_common_rating_range = rating_counts.idxmax()

print(f"Most Common Rating Range: {most_common_rating_range}")

# Calculate the average number of votes received by restaurants
average_votes = df['Votes'].mean()

print(f"\nAverage Number of Votes Received by Restaurants: {average_votes:.2f}")
# Out:
# Most Common Rating Range: 0.0
#
# Average Number of Votes Received by Restaurants: 156.91

# %% [markdown]
# # Level 2 - Task 2 : "Cuisine Combination"

# %% [markdown]
# # Identify the most common combinations of cuisines in the dataset.

# %% [markdown]
# # Determine if certain cuisine combinations tend to have higher ratings.

# %%
# Extract unique cuisine combinations
unique_combinations = df['Cuisines'].str.split(', ').explode().unique()

# Create a new DataFrame to store the combinations and their counts
combination_counts = pd.DataFrame(columns=['Combination', 'Count', 'Average Rating'])

# Iterate over unique combinations and calculate counts and average ratings
for combination in unique_combinations:
    combination_filter = df['Cuisines'].apply(lambda x: str(x).lower().find(str(combination).lower())
                                               != -1 if pd.notna(x) else False)
    combination_count = combination_filter.sum()
    average_rating = df.loc[combination_filter, 'Aggregate rating'].mean()

    combination_counts = combination_counts.append({
        'Combination': combination,
        'Count': combination_count,
        'Average Rating': average_rating
    }, ignore_index=True)

# Sort the DataFrame by count in descending order
combination_counts = combination_counts.sort_values(by='Count', ascending=False)

print("Most Common Cuisine Combinations:")
print(combination_counts[['Combination', 'Count']])

print("\nAverage Ratings for Cuisine Combinations:")
print(combination_counts[['Combination', 'Average Rating']])
# Out:
# Most Common Cuisine Combinations:
#            Combination Count
# 6               Indian  4259
# 82        North Indian  3960
# 9              Chinese  2733
# 19           Fast Food  1987
# 83             Mughlai   994
# 15             Italian   764
# 17              Bakery   744
# 72         Continental   736
# 14                Cafe   707
# 2             Desserts   653
# 85        South Indian   636
# 51                Thai   614
# 90         Street Food   562
# 12            American   405
# 16               Pizza   389
# 96              Mithai   380
# 27              Burger   251
# 4                Asian   234
# 30           Beverages   228
# 13           Ice Cream   226
# 11             Mexican   181
# 84             Biryani   177
# 3              Seafood   174
# 29        Healthy Food   150
# 10            European   148
# 1             Japanese   135
# 60                 Tea   129
# 78         Finger Food   114
# 105          Raw Meats   114
# 18       Mediterranean   112
# 65               Salad    93
# 7                Sushi    75
# 31            Lebanese    69
# 33               Steak    62
# 32            Sandwich    53
# 104            Tibetan    44
# 42           Breakfast    41
# 22            Bar Food    39
# 34                 BBQ    33
# 0               French    29
# 110            Bengali    29
# 28              Juices    29
# 21             Arabian    28
# 20           Brazilian    28
# 88          Hyderabadi    26
# 23               Grill    25
# 44            Southern    24
# 74               Malay    23
# 69             Turkish    23
# 40          Vegetarian    23
# 106             Kerala    23
# 100          Malaysian    22
# 57      Middle Eastern    22
# 89          Rajasthani    21
# 8               Korean    21
# 24       International    21
# 50          Vietnamese    21
# 91                Goan    20
# 108           Kashmiri    20
# 41               Tapas    19
# 56             Tex-Mex    19
# 39      Coffee and Tea    19
# 77             Western    17
# 79             British    16
# 46             Spanish    16
# 98       Modern Indian    16
# 58               Greek    15
# 61          Australian    15
# 92             African    14
# 81          Indonesian    14
# 87             Afghani    14
# 112           Lucknowi    13
# 86           Pakistani    12
# 52   Modern Australian    11
# 26      Latin American    11
# 94            Gujarati    11
# 113             Awadhi    11
# 102          Chettinad    11
# 49              German    10
# 97       Maharashtrian    10
# 101            Burmese    10
# 5             Filipino    10
# 139              Kebab    10
# 54               Cajun    10
# 119             Andhra    10
# 114           Nepalese     9
# 133       Contemporary     9
# 37       North Eastern     9
# 124               Naga     8
# 103              Parsi     8
# 140      Turkish Pizza     8
# 64            Hawaiian     8
# 45        Southwestern     7
# 48           Caribbean     7
# 93          Portuguese     7
# 137      South African     6
# 43               Diner     6
# 129               Kiwi     6
# 135              Curry     6
# 117             Bihari     6
# 125         Sri Lankan     5
# 123           Moroccan     5
# 62              Fusion     5
# 136         Patisserie     4
# 120        Mangalorean     4
# 142      World Cuisine     4
# 118           Assamese     4
# 144    Restaurant Cafe     4
# 73         Singaporean     4
# 99      Charcoal Grill     4
# 127              Sunda     3
# 111            Iranian     3
# 95            Armenian     3
# 80                Deli     3
# 76             Dim Sum     3
# 134           Scottish     3
# 107            Belgian     2
# 141             Izgara     2
# 47           Argentine     2
# 53            Teriyaki     2
# 131          Taiwanese     2
# 130       Asian Fusion     2
# 63               Cuban     2
# 128              Ramen     2
# 109     South American     2
# 116              Oriya     2
# 67        New American     2
# 70            Pub Food     2
# 115        Drinks Only     2
# 71             Persian     2
# 75           Cantonese     2
# 66               Irish     1
# 25            Peruvian     1
# 143           Dï¿½_ner     1
# 35   Gourmet Fast Food     1
# 36             Mineira     1
# 138             Durban     1
# 55            Canadian     1
# 126          Peranakan     1
# 59          Bubble Tea     1
# 132     Fish and Chips     1
# 121            Malwani     1
# 122     Cuisine Varies     1
# 68           Soul Food     1
# 145           Bï¿½_rek     1
# 38                 NaN   0.0
#
# Average Ratings for Cuisine Combinations:
#            Combination  Average Rating
# 6               Indian        2.525053
# 82        North Indian        2.510455
# 9              Chinese        2.620234
# 19           Fast Food        2.563966
# 83             Mughlai        2.612575
# 15             Italian        3.562042
# 17              Bakery        2.440054
# 72         Continental        3.518750
# 14                Cafe        3.325177
# 2             Desserts        2.978867
# 85        South Indian        2.469811
# 51                Thai        2.678176
# 90         Street Food        2.356050
# 12            American        3.673827
# 16               Pizza        2.950643
# 96              Mithai        2.073684
# 27              Burger        3.520717
# 4                Asian        3.816667
# 30           Beverages        2.733333
# 13           Ice Cream        2.583186
# 11             Mexican        3.723204
# 84             Biryani        2.420339
# 3              Seafood        3.862069
# 29        Healthy Food        3.081333
# 10            European        3.910811
# 1             Japanese        3.797037
# 60                 Tea        3.529457
# 78         Finger Food        3.276316
# 105          Raw Meats        2.152632
# 18       Mediterranean        3.948214
# 65               Salad        3.165591
# 7                Sushi        3.973333
# 31            Lebanese        3.433333
# 33               Steak        3.985484
# 32            Sandwich        4.066038
# 104            Tibetan        2.302273
# 42           Breakfast        3.965854
# 22            Bar Food        3.933333
# 34                 BBQ        3.903030
# 0               French        3.862069
# 110            Bengali        3.006897
# 28              Juices        2.993103
# 21             Arabian        3.385714
# 20           Brazilian        3.567857
# 88          Hyderabadi        3.515385
# 23               Grill        4.076000
# 44            Southern        4.129167
# 74               Malay        3.730435
# 69             Turkish        3.804348
# 40          Vegetarian        4.073913
# 106             Kerala        3.478261
# 100          Malaysian        3.763636
# 57      Middle Eastern        3.763636
# 89          Rajasthani        3.180952
# 8               Korean        3.652381
# 24       International        4.247619
# 50          Vietnamese        3.923810
# 91                Goan        3.970000
# 108           Kashmiri        2.935000
# 41               Tapas        4.131579
# 56             Tex-Mex        3.884211
# 39      Coffee and Tea        3.794737
# 77             Western        4.158824
# 79             British        4.112500
# 46             Spanish        4.081250
# 98       Modern Indian        4.281250
# 58               Greek        3.693333
# 61          Australian        3.553333
# 92             African        3.871429
# 81          Indonesian        4.285714
# 87             Afghani        1.971429
# 112           Lucknowi        2.384615
# 86           Pakistani        3.708333
# 52   Modern Australian        3.527273
# 26      Latin American        4.063636
# 94            Gujarati        3.354545
# 113             Awadhi        1.572727
# 102          Chettinad        3.672727
# 49              German        3.970000
# 97       Maharashtrian        3.570000
# 101            Burmese        4.050000
# 5             Filipino        4.340000
# 139              Kebab        4.380000
# 54               Cajun        4.200000
# 119             Andhra        3.870000
# 114           Nepalese        1.655556
# 133       Contemporary        4.288889
# 37       North Eastern        2.088889
# 124               Naga        3.475000
# 103              Parsi        4.100000
# 140      Turkish Pizza        4.325000
# 64            Hawaiian        4.412500
# 45        Southwestern        4.185714
# 48           Caribbean        4.271429
# 93          Portuguese        3.357143
# 137      South African        4.333333
# 43               Diner        3.866667
# 129               Kiwi        4.300000
# 135              Curry        4.400000
# 117             Bihari        3.650000
# 125         Sri Lankan        3.580000
# 123           Moroccan        1.620000
# 62              Fusion        3.700000
# 136         Patisserie        4.025000
# 120        Mangalorean        3.725000
# 142      World Cuisine        4.300000
# 118           Assamese        2.400000
# 144    Restaurant Cafe        4.025000
# 73         Singaporean        3.175000
# 99      Charcoal Grill        4.175000
# 127              Sunda        4.900000
# 111            Iranian        4.066667
# 95            Armenian        1.300000
# 80                Deli        4.200000
# 76             Dim Sum        4.466667
# 134           Scottish        4.333333
# 107            Belgian        4.050000
# 141             Izgara        4.350000
# 47           Argentine        4.300000
# 53            Teriyaki        4.300000
# 131          Taiwanese        4.650000
# 130       Asian Fusion        3.850000
# 63               Cuban        4.150000
# 128              Ramen        4.500000
# 109     South American        3.500000
# 116              Oriya        3.250000
# 67        New American        4.100000
# 70            Pub Food        3.950000
# 115        Drinks Only        1.750000
# 71             Persian        2.300000
# 75           Cantonese        3.850000
# 66               Irish        4.300000
# 25            Peruvian        3.600000
# 143           Dï¿½_ner        4.400000
# 35   Gourmet Fast Food        4.300000
# 36             Mineira        0.000000
# 138             Durban        4.300000
# 55            Canadian        3.000000
# 126          Peranakan        4.000000
# 59          Bubble Tea        4.400000
# 132     Fish and Chips        4.300000
# 121            Malwani        3.500000
# 122     Cuisine Varies        0.000000
# 68           Soul Food        3.600000
# 145           Bï¿½_rek        4.700000
# 38                 NaN             NaN

# %% [markdown]
# # Level 2 - Task 3 : "Geographic Analysis"

# %% [markdown]
# # Plot the locations of restaurants on a map using longitude and latitude coordinates.

# %% [markdown]
# # Identify any patterns or clusters of restaurants in specific areas.

# %%
import folium
from folium.plugins import MarkerCluster

# Filter out rows with missing latitude or longitude values
df = df.dropna(subset=['Latitude', 'Longitude'])

# Create a map centered around the average latitude and longitude
average_latitude = df['Latitude'].mean()
average_longitude = df['Longitude'].mean()
restaurant_map = folium.Map(location=[average_latitude, average_longitude], zoom_start=12)

# Create a MarkerCluster to group nearby markers
marker_cluster = MarkerCluster().add_to(restaurant_map)

# Add markers for each restaurant
for index, row in df.iterrows():
    folium.Marker(location=[row['Latitude'], row['Longitude']],
                  popup=row['Restaurant Name']).add_to(marker_cluster)

# Save the map as an HTML file or display it
restaurant_map.save('restaurant_map.html')
# restaurant_map  # Uncomment this line to display the map in Jupyter Notebook (may not work in all environments)

# %% [markdown]
# # Level 2 - Task 4 : "Restaurant Chains"

# %% [markdown]
# # Identify if there are any restaurant chains present in the dataset.

# %% [markdown]
# # Analyze the ratings and popularity of different restaurant chains.

# %%
# Identify restaurant chains based on the 'Restaurant Name'
restaurant_chains = df['Restaurant Name'].value_counts()

# Filter out individual restaurants (considering chains with multiple locations)
chains = restaurant_chains[restaurant_chains > 1].index

# Create a DataFrame for restaurant chains
chain_df = df[df['Restaurant Name'].isin(chains)].copy()

# Analyze ratings and popularity of different restaurant chains
chain_analysis = chain_df.groupby('Restaurant Name').agg({
    'Aggregate rating': 'mean',
    'Votes': 'sum',
    'Average Cost for two': 'mean'
}).sort_values(by='Votes', ascending=False)

# Display the analysis
print("Restaurant Chains Analysis:")
print(chain_analysis)
# Out:
# Restaurant Chains Analysis:
#                                            Aggregate rating  Votes  \
# Restaurant Name
# Barbeque Nation                                    4.353846  28142
# AB's - Absolute Barbecues                          4.825000  13400
# Big Chill                                          4.475000  10853
# Farzi Cafe                                         4.366667  10098
# Truffles                                           3.950000   9682
# Chili's                                            4.580000   8156
# Joey's Pizza                                       4.250000   7807
# Big Yellow Door                                    4.266667   7511
# Saravana Bhavan                                    4.133333   7238
# Starbucks                                          3.805556   7139
# Pirates of Grill                                   4.025000   7091
# Karim's                                            3.030769   6878
# Domino's Pizza                                     2.740506   6643
# Subway                                             2.907937   6124
# Dunkin' Donuts                                     3.136364   5974
# Pind Balluchi                                      2.630000   5582
# Talaga Sampireun                                   4.900000   5514
# Punjab Grill                                       4.340000   5424
# Berco's                                            3.166667   5394
# SodaBottleOpenerWala                               4.066667   5374
# McDonald's                                         3.339583   5291
# Tea Villa Cafe                                     3.925000   5167
# Pizza Hut                                          3.320000   4961
# Out Of The Box                                     3.850000   4900
# Burger King                                        3.406250   4617
# Khan Chacha                                        2.471429   4610
# Haldiram's                                         3.625000   4525
# TGI Friday's                                       3.850000   4357
# Nando's                                            3.140000   4045
# Sagar Ratna                                        2.963158   4038
# Olive Bistro                                       4.150000   3708
# SpiceKlub                                          4.300000   3651
# QD's Restaurant                                    4.033333   3536
# Hard Rock Cafe                                     4.200000   3491
# Wood Box Cafe                                      3.950000   3449
# AB's Absolute Barbecues                            4.850000   3151
# The Flying Saucer Cafe                             4.100000   3145
# Mocha                                              4.185714   3111
# Naturals Ice Cream                                 4.800000   3094
# Desi Vibes                                         3.900000   3043
# The Cheesecake Factory                             4.650000   3010
# Bikanervala                                        3.192857   2980
# Raasta                                             3.850000   2943
# Onesta                                             4.500000   2821
# Cafe Delhi Heights                                 4.033333   2711
# Jungle Jamboree                                    3.825000   2705
# Mamagoto                                           4.166667   2633
# Imperfecto                                         3.550000   2546
# Mainland China                                     3.716667   2541
# Naivedyam                                          3.866667   2481
# Chaayos                                            3.538889   2473
# Cafe Coffee Day                                    2.419277   2428
# Nizam's Kathi Kabab                                3.650000   2356
# KFC                                                2.744444   2331
# Kake Da Hotel                                      3.280000   2327
# Smoke House Deli                                   4.050000   2292
# Palmshore                                          4.300000   2228
# The Chatter House                                  4.100000   2136
# Punjabi By Nature                                  3.700000   2026
# Oh! Calcutta                                       4.100000   1999
# Ceviche Tapas Bar & Restaurant                     4.250000   1993
# The Beer Cafe                                      3.016667   1987
# Bombay Brasserie                                   4.400000   1984
# Gola Sizzlers                                      3.300000   1968
# Yo! China                                          2.988889   1951
# Made In Punjab                                     4.050000   1917
# Effingut Brewerkz                                  4.300000   1906
# Amici Cafe                                         3.700000   1896
# Bikkgane Biryani                                   3.966667   1882
# Swagath                                            3.620000   1819
# RollsKing                                          3.700000   1814
# Indian Coffee House                                3.533333   1811
# Garam Dharam                                       3.550000   1805
# The Junkyard Cafe                                  3.850000   1765
# Pita Pit                                           3.700000   1703
# Pebble Street                                      3.950000   1703
# Imly                                               3.900000   1689
# Zaffran                                            4.166667   1661
# Not Just Paranthas                                 3.333333   1647
# Nazeer Foods                                       3.328571   1628
# Caffe Tonino                                       3.850000   1604
# Shake Square                                       3.650000   1594
# Ichiban                                            4.100000   1533
# Deez Biryani & Kebabs                              3.650000   1532
# Teddy Boy                                          3.750000   1527
# Pizza Hut Delivery                                 2.657895   1527
# The Yellow Chilli                                  3.671429   1526
# Whipped                                            4.200000   1497
# Happy Hakka                                        3.860000   1471
# Captain Grub                                       3.540000   1408
# Sbarro                                             3.400000   1408
# Instapizza                                         3.800000   1406
# Slice of Italy                                     2.728571   1377
# Paradise                                           3.700000   1374
# Zizo                                               3.866667   1371
# Silantro Fil-Mex                                   4.850000   1364
# Gazebo                                             4.166667   1279
# Dishoom                                            4.600000   1269
# Keventers                                          2.870588   1263
# Krispy Kreme                                       3.933333   1257
# Angels in my Kitchen                               3.412500   1241
# Matchbox                                           4.400000   1214
# Town Hall                                          3.650000   1199
# China Garden                                       3.850000   1159
# Giani's                                            2.781818   1150
# Wow! Momo                                          2.754545   1119
# The Crab Shack                                     3.950000   1112
# The Midnight Heroes                                3.660000   1111
# Shree Rathnam                                      3.000000   1083
# The Big Chill Cakery                               4.450000   1059
# Applebee's                                         3.900000   1057
# L'Opera                                            3.820000   1046
# Asian Haus                                         4.000000   1046
# The Great Kabab Factory                            3.500000   1038
# DCK- Dana Choga's Kitchen                          3.125000   1037
# Caffe 9                                            4.200000   1030
# Wah Ji Wah                                         2.342105   1026
# Moti Mahal Delux                                   3.000000   1023
# The Fisherman's Wharf                              4.266667   1022
# Changezi Chicken                                   3.500000   1017
# Nathu's Sweets                                     2.720000   1003
# BTW                                                3.285714    998
# Din Tai Fung                                       4.350000    997
# Green Chick Chop                                   2.672549    964
# San Carlo                                          4.250000    893
# Side Wok                                           3.866667    875
# The Barbeque Company                               4.000000    869
# Costa Coffee                                       2.415000    861
# Cafe Turtle                                        3.433333    861
# The Coffee Bean & Tea Leaf                         3.425000    855
# Giani                                              2.689655    854
# Suruchi                                            3.600000    836
# Embassy                                            3.250000    832
# Baker Street                                       3.850000    831
# Taco Bell                                          3.866667    825
# Munch Nation                                       3.900000    823
# Barista                                            3.072727    815
# Wendy's                                            3.800000    814
# Chili's Grill & Bar                                3.950000    813
# Baking Bad                                         3.750000    795
# Defence Bakery                                     3.700000    791
# Harry's Bar + Cafe                                 3.650000    787
# Chowringhee                                        2.562500    785
# Texas Roadhouse                                    3.860000    783
# Rhinehart's Oyster Bar                             4.000000    782
# 34, Chowringhee Lane                               2.791667    777
# Biryani Blues                                      3.666667    776
# Colonel's Kababz                                   3.200000    766
# Cinnabon                                           4.000000    757
# Burger Singh                                       3.433333    757
# Qureshi's Kabab Corner                             3.575000    744
# Smaaash                                            3.950000    743
# Khidmat                                            3.500000    741
# Natural Ice Cream                                  4.500000    732
# Rollmaal                                           3.400000    719
# Circus                                             3.950000    719
# Kebab Xpress                                       3.025000    708
# Eggers Madhouse                                    3.850000    698
# Kake Di Hatti                                      3.550000    678
# The National                                       4.150000    677
# Mad Over Donuts                                    3.740000    676
# Italiano                                           3.300000    674
# 10 Downing Street                                  4.000000    670
# Perch Wine & Coffee Bar                            4.250000    665
# Jamie's Italian                                    4.050000    663
# Southy                                             2.716667    643
# Om Sweets & Snacks                                 3.133333    638
# Chicago Pizza                                      2.325000    633
# Gung The Palace                                    3.950000    630
# Granite City Food & Brewery                        4.050000    628
# Mellow Mushroom                                    4.250000    625
# Chai Point                                         3.100000    623
# Speedy Chow                                        3.466667    623
# HuHot Mongolian Grill                              3.766667    618
# Bun Intended                                       3.950000    615
# Dï¿½_ner Grill                                     3.800000    590
# The Cafe                                           4.350000    590
# Burger Point                                       3.145455    574
# Nanking                                            3.650000    569
# Bhimsain's Bengali Sweet House                     3.150000    564
# Cocoberry                                          3.422222    564
# Open Oven                                          3.475000    553
# Biryani By Kilo                                    4.000000    553
# Cafe Brown Sugar                                   3.650000    551
# Red Mango                                          3.650000    550
# Goli Vada Pav No. 1                                2.750000    548
# Kebab Gali                                         3.900000    544
# Wok On Fire                                        3.800000    542
# Theos                                              3.800000    529
# Basil Tree                                         2.900000    527
# Bijoli Grill                                       3.700000    525
# MR.D - Deliciousness Delivered                     3.400000    515
# Kolkata Biryani House                              3.100000    513
# Au Bon Pain                                        3.250000    511
# Wrapss                                             2.566667    510
# Hong Kong Express                                  3.475000    510
# Crazy Noodles                                      1.800000    509
# Behrouz Biryani                                    3.184615    509
# Nite Bites                                         3.175000    507
# Chaophraya                                         4.166667    505
# Carl's Jr.                                         3.650000    503
# The Breakfast Club                                 4.000000    502
# Moti Mahal Delux Tandoori Trail                    2.733333    501
# Delhi Club House                                   4.000000    497
# Apni Rasoi                                         1.941667    489
# Fish Streat                                        3.700000    483
# Manohar Dairy And Restaurant                       4.250000    481
# Nooba                                              3.700000    481
# Nirula's                                           2.650000    478
# Kaveri Restaurant And Caterers                     3.700000    472
# Twigly                                             4.550000    471
# FreshMenu                                          3.725000    467
# Invitation                                         1.800000    460
# Hungry - I                                         3.150000    457
# Cafe Diva                                          3.850000    456
# Bake N Shake                                       4.200000    446
# Wai Yu Mun Ching                                   3.550000    433
# Puri Bakers                                        3.725000    432
# Baskin Robbins                                     1.860714    428
# Tipu Sultan                                        3.850000    427
# Burgrill                                           4.450000    427
# Hawkers                                            3.050000    424
# Metro Dhaba                                        1.900000    419
# Nutritious Nation                                  3.550000    416
# The Creamery                                       4.050000    415
# Cafe Coffee Day The Square                         3.650000    410
# Adyar Ananda Bhavan                                3.150000    407
# New Town Cafe - Park Plaza                         3.900000    404
# Urban Punjab                                       3.433333    403
# Sanjha Chulha                                      2.416667    398
# Chinese Corner                                     1.240000    398
# Arabian Nites                                      3.650000    397
# Chokola                                            3.450000    397
# Al Bake                                            2.950000    396
# La Pino'z Pizza                                    3.966667    394
# Kamal's                                            3.250000    389
# Madras Cafe                                        1.918182    389
# Goosebumps                                         3.800000    387
# Barbeque Ville                                     4.100000    372
# Aureo Dine & Bake House                            1.750000    370
# Chawla'sï¿½_                                       2.271429    364
# Big Wong XL                                        3.950000    361
# Biryani Art                                        3.700000    352
# Dilli BC                                           4.250000    351
# Sugar & Spice - Le Marche                          2.900000    351
# Anjlika Pastry Shop                                3.750000    349
# Underdoggs Sports Bar & Grill                      4.350000    346
# Burger Hut                                         3.200000    335
# The Mad Teapot/The Wishing Chair                   4.250000    334
# Beliram Degchiwala                                 3.500000    333
# Habibi                                             3.400000    330
# Cafe Coffee Day - The Lounge                       2.800000    330
# Gymkhana                                           4.700000    328
# Americana Kitchen and Bar                          2.600000    326
# Finger Licious                                     2.200000    325
# Fat Lulu's                                         3.750000    319
# Spice Route                                        3.500000    319
# Paapi Paet                                         3.450000    318
# Ashoka Restaurant                                  3.550000    318
# Little Chef                                        3.400000    318
# Kamboj's                                           2.600000    315
# The Diet Kitchen                                   3.750000    314
# Sandwich King                                      3.650000    314
# Food Scouts                                        4.433333    312
# Litti.In                                           3.400000    312
# Tikka Town                                         3.033333    309
# All About Food                                     1.950000    305
# Bon Bon Pastry Shop                                3.300000    304
# The Golden Dragon                                  2.833333    304
# Doughlicious                                       3.500000    304
# Alaturka                                           2.950000    302
# Comesum                                            2.350000    300
# Mysore Cafe                                        3.600000    291
# Mr. Brown                                          3.866667    285
# Dï¿½_veroï¿½ï¿½lu                                  4.300000    283
# Khana Khazana                                      1.850000    281
# Twenty Four Seven                                  2.147368    280
# Blue Tokai Coffee Roasters                         3.850000    279
# Baked Buns                                         3.400000    273
# Captain Bill$ Deliverz                             2.533333    273
# Mitra Da Dhaba                                     2.100000    273
# Otik Cake Shop                                     3.650000    271
# Chalte Firte Momos & Special Foods                 3.350000    267
# Gopala                                             3.290000    264
# Chinese Hut                                        2.728571    261
# Tibb's Frankie                                     2.842857    260
# Pudding & Pie                                      3.166667    258
# Chutneez Restaurant Lounge & Bar                   2.550000    256
# Shawarma Wala                                      2.066667    255
# Pho King Awesome                                   2.050000    254
# Movenpick                                          3.966667    253
# Big Fat Sandwich                                   3.200000    253
# Bakers Oven                                        3.600000    252
# Hwealthcafe                                        3.800000    252
# New Kadimi                                         2.900000    252
# Moti Mahal Delux- Legendary Culinary               3.600000    249
# Drifters Cafe                                      4.000000    248
# Red Chilli                                         2.500000    247
# The Kathis                                         3.000000    247
# Zaika                                              2.850000    245
# Viva Hyderabad                                     2.380000    243
# Twisted Tacos                                      3.600000    242
# Beijing Street                                     3.700000    242
# Baker's Stop                                       3.750000    241
# Sibang Bakery                                      3.700000    240
# Drool Waffles                                      3.650000    237
# Republic of Chicken                                2.422222    234
# Hot Pot                                            2.075000    232
# Kanwarji's                                         3.433333    232
# Little Italy                                       3.550000    227
# Oberoi Biryani                                     2.750000    225
# Sandoz                                             2.400000    225
# Dabba Meat                                         3.250000    224
# Black Pepper                                       2.050000    223
# Punjabi Zaika                                      2.350000    223
# Punjabi Chaap Corner                               2.350000    221
# Chaska                                             2.375000    220
# Green Leaf                                         3.250000    220
# The Artful Baker                                   2.000000    220
# First Eat                                          3.800000    219
# Mr. Sub                                            2.583333    217
# 221 B Baker Street                                 3.366667    215
# Arabian Delites                                    3.600000    214
# The Chocolate Room                                 3.500000    214
# Kerala Cafe                                        3.066667    214
# Timboo Cafe                                        4.200000    213
# Shyam Sweets                                       3.450000    209
# Stop My Starvation                                 4.300000    209
# Fast Trax                                          3.300000    207
# Punjabi Rasoi                                      1.250000    207
# The Chai Story                                     3.700000    206
# Nukkadwala                                         2.820000    206
# Mithaas                                            3.050000    205
# Flying Cakes                                       2.233333    205
# Dilli Darbar                                       3.100000    204
# The Pint Room                                      3.700000    203
# Hot Cherries                                       3.600000    200
# Punjabi Pakwaan                                    3.133333    199
# Patiala Shahi                                      3.450000    196
# Chawla's Tandoori Junction                         2.266667    195
# Bengal Sweet Corner                                2.800000    192
# Say Cheese                                         2.700000    192
# Chick-fil-A                                        3.700000    192
# Moon Bite                                          3.200000    190
# Big Dragon                                         3.350000    189
# Dunkin Donuts                                      4.000000    188
# Jahangeer Foods                                    3.250000    188
# Yumm Biryani                                       3.200000    187
# Crudo Juicery                                      4.300000    187
# SGF - Spice Grill Flame                            3.200000    187
# Taste of India                                     2.100000    186
# Chawla's                                           3.350000    185
# Nazeer Delicacies                                  3.300000    184
# Punjabi Tadka                                      2.550000    182
# Tamura                                             3.400000    182
# Let's Noodle                                       1.300000    182
# Dezertfox                                          3.900000    181
# La Americana                                       3.650000    180
# Fit Bites                                          3.750000    180
# Habibi Express                                     1.500000    177
# 4700BC Popcorn                                     3.500000    176
# Hungry Minister                                    3.500000    176
# Kathi Junction                                     1.625000    174
# Cake Palace                                        3.250000    171
# Kulcha King                                        1.900000    170
# Sethi's The Cake Shop                              3.350000    166
# Nagpal's                                           3.450000    166
# The Tandoor                                        3.000000    166
# Burger Joint                                       1.750000    165
# Perfect Bake                                       3.550000    165
# Cook Du Kdu                                        3.150000    164
# Caffï¿½ï¿½ La Poya                                 1.850000    164
# Moksha                                             3.450000    164
# Kanha Sweets                                       3.450000    164
# Hunger Strike                                      3.500000    162
# Roll Club                                          3.066667    162
# Los Agaves                                         2.050000    160
# Hornbill                                           3.550000    156
# The Chinese Hut                                    2.860000    155
# Sri Balaji                                         2.333333    155
# Chawla's Chic Inn                                  3.033333    155
# Cones & Curries                                    1.850000    153
# Hotel Malabar                                      3.300000    153
# Paramjeet Machi Wala                               3.500000    152
# High On Burgers                                    3.350000    152
# Frozen Factory                                     3.800000    151
# Tikka Junction                                     3.433333    150
# Country Curries                                    3.100000    147
# Ashok Meat Wala                                    3.550000    146
# Manohar Bikkaneri                                  3.700000    145
# Sushiya Express                                    3.633333    144
# Foodhall                                           2.533333    143
# Shawarma King's                                    3.400000    143
# Bobby Tikki Wala                                   2.900000    143
# Gupta Chat Corner                                  3.500000    143
# Bhoj Restaurant                                    3.250000    143
# Koyla Kebab                                        3.350000    141
# Hira Sweets                                        3.033333    140
# Le Chef                                            3.150000    140
# Polka Pastry & Snack Bar                           3.100000    139
# Punjab Restaurant                                  3.266667    137
# Jaiveer Naan & Chaap                               2.900000    133
# Food Express                                       1.800000    128
# Night Food Xprs                                    2.700000    127
# Pakwan                                             2.075000    126
# Frontier                                           2.828571    125
# Momo-Cha                                           2.725000    124
# Muffins                                            2.700000    122
# Chawla's Tandoori Xpress                           2.850000    120
# Hot Stuff                                          3.400000    119
# Tea Halt                                           2.866667    118
# Laxmi Ice Cream                                    3.550000    118
# Angeethi                                           3.050000    118
# Nirula's Ice Cream                                 2.400000    117
# Chawnsan Chef                                      3.400000    117
# buï¿½ï¿½no                                         3.750000    117
# Pasta Hut                                          3.400000    116
# Burger Xpress                                      1.625000    116
# Chawla's 2                                         1.700000    116
# Midnight Hunger Hub                                4.033333    114
# Gullu's                                            3.000000    114
# Veg Ex                                             3.600000    113
# Rainbows                                           3.100000    113
# New Punjabi Khana                                  3.500000    112
# Sardar A Pure Meat Shop                            1.722222    112
# Coldpress Company                                  4.050000    108
# Bats On Delivery                                   2.700000    108
# Public Cafe                                        2.400000    107
# Punjabi Dhaba                                      2.200000    107
# Kolkata Kathi Roll                                 3.100000    106
# Oh Buoy                                            3.350000    105
# Grillz                                             2.350000    104
# Raj Restaurant                                     2.750000    103
# Singz                                              2.700000    103
# Halki Aanch                                        3.000000    103
# Wagh Bakri Tea Lounge                              3.600000    102
# The Culinary Pitaara                               3.500000    102
# Chawla Family Restaurant                           3.050000    101
# Ovenstory Pizza                                    2.500000    100
# Relax Xpress                                       3.200000    100
# GoGourmet                                          2.650000     99
# Hasty Tasty                                        2.033333     99
# Shri Ram Restaurant                                2.850000     98
# The Bake Studio                                    3.350000     98
# Just Vada Pav                                      1.200000     97
# South Cafe                                         1.750000     96
# Prince Chaat Corner                                3.450000     96
# Chimney                                            3.033333     95
# Biryaniwala                                        2.350000     94
# Bikano Chat Cafe                                   2.800000     93
# Hurry's Paratha                                    3.500000     92
# Cakes & Bakes                                      3.166667     92
# Muradabadi Shahi Biryani & Chicken Corner          1.966667     92
# Sumo Sushi                                         3.950000     91
# Madras Dosa & Chinese                              1.350000     91
# Go Kylin                                           3.150000     90
# Shankar Fast Food                                  2.950000     89
# Flirty Momo's                                      2.920000     89
# South Indian Corner                                3.400000     89
# Bikaner Sweets                                     1.338462     88
# JSB Evergreen Snack & Sweets                       3.150000     88
# Pitstop                                            1.650000     87
# Bawarchi                                           3.125000     86
# Flavours                                           3.100000     85
# BarShala                                           3.266667     85
# The Dosa King                                      3.050000     84
# Bunty Dhaba                                        2.833333     84
# Madhuvan Chinese Fast Food                         2.600000     84
# Oberoi's                                           3.400000     83
# Kings Kulfi                                        2.266667     82
# Spooky Sky                                         3.450000     82
# Vaishno Punjabi Dhaba                              3.250000     82
# Zaaika Junction                                    2.850000     81
# Qureshi Kabab Corner                               3.650000     81
# A Piece of Paris                                   3.750000     81
# ZASTY                                              3.500000     80
# Street Foods by Punjab Grill                       1.933333     79
# Kumar Pastry Shop                                  3.250000     79
# Chinese King                                       2.500000     77
# Faasos                                             2.937500     77
# Raj Rasoi                                          1.650000     76
# Druk                                               3.450000     75
# Riyaz Chicken Corner                               1.700000     75
# Hyderabad House                                    3.100000     74
# Wheelyz                                            2.850000     73
# KB's Kulfi & Icecream                              3.133333     73
# Shahenshah                                         3.133333     72
# Brijwasi Restaurant                                3.000000     71
# Gelato Vinto                                       2.975000     70
# Shama Chicken Corner                               1.077778     69
# Shree Bikaner Misthan Bhandar                      3.000000     69
# China Town                                         2.028571     68
# True Blue                                          3.166667     68
# The Kitchen                                        2.950000     67
# Mitthu Tikki Wala                                  3.300000     67
# Fabulous Cake Bites                                3.500000     67
# Reena Restaurant                                   3.100000     66
# Bharat Sweets                                      3.333333     65
# Haldiram Bhujiawala                                3.450000     62
# Shree Durga Dosa                                   3.050000     62
# Vadapav Junction                                   3.450000     62
# Papa Veg Chinese Food                              3.350000     62
# Aggarwal Sweets India                              1.733333     61
# Hot Joint Fast Food                                1.300000     61
# South Indian Cafe                                  3.000000     60
# Senorita's                                         1.850000     60
# Hangchuaa's Chinese Food Corner                    2.966667     60
# Bake Club                                          3.150000     59
# The Blue Tandoor                                   2.750000     59
# Garota de Ipanema                                  4.600000     59
# Tea Trails                                         1.850000     58
# Havmor Ice Cream                                   3.366667     57
# Mithaas Sweets                                     2.900000     56
# Roti Aur Boti                                      3.350000     56
# Kolkata Hot Kathi Roll                             2.950000     56
# Weird Time Food                                    3.350000     56
# Miam                                               3.550000     55
# Ammu's South Indian Restaurant                     2.950000     55
# Kitchen King                                       1.300000     55
# Midnight Hunger                                    3.450000     55
# Sonya Bakery Cafe                                  3.400000     54
# Punjabee's Darbar                                  3.150000     53
# Kati Roll Cottage                                  3.600000     53
# Nawabi Mughlai Zaika                               3.250000     53
# Zooby's Kitchen                                    3.150000     52
# Jack Po!tato's                                     3.400000     52
# The Night Owl                                      1.400000     52
# Urban Dhaba                                        2.850000     51
# Clever Fox Cafe                                    3.100000     51
# Gulab                                              2.950000     51
# Pandey Chinese Hut                                 2.700000     50
# Mirchievous                                        3.500000     50
# Gupta Ji Ka Dhaba                                  1.300000     49
# Cake Point                                         1.740000     49
# Ramesh Vaishno Dhaba                               3.100000     48
# Coco Bambu                                         4.550000     47
# New Madras Cafe                                    1.966667     47
# Green Restaurant                                   1.800000     47
# Wah G Wah                                          1.766667     46
# Fresh n Refresh                                    3.100000     46
# New Zaika                                          2.750000     45
# Bhappe Di Hatti                                    3.300000     45
# The Cake Shop                                      1.650000     44
# Super Snacks                                       1.550000     44
# Tpot                                               0.971429     43
# Metro Fast Food                                    2.650000     43
# South Indian Hut                                   1.575000     43
# EDC Mania                                          1.650000     41
# Aggarwal Sweet Corner                              1.260000     41
# Shamji Sweets                                      3.050000     41
# Health Buzzz                                       3.133333     40
# Aggarwal Sweets                                    0.792857     39
# Breaktym                                           2.766667     37
# Snack Junction                                     3.100000     37
# Momos House                                        3.100000     37
# Chao Cart                                          3.200000     36
# Aggarwal Sweet India                               1.700000     35
# Pizza Diet                                         2.750000     35
# Liquid                                             3.600000     35
# Mahi Rasoi                                         1.300000     34
# Chaap Point                                        3.200000     34
# Faaso's                                            1.800000     34
# Aapki Rasoi                                        1.525000     34
# Fluffles - The Fluffy Waffle Co.                   3.000000     34
# China Hut                                          2.700000     34
# Spanish Delights                                   3.300000     33
# Ram Chinese Food                                   3.000000     32
# Khalsa Veg Corner                                  3.250000     32
# The Belgian Fries Company                          1.850000     32
# Konetto Pizza                                      1.750000     32
# Standard Sweets                                    1.800000     32
# Pizza Yum                                          2.900000     32
# 34 Parkstreet Lane                                 3.050000     31
# The Chef                                           2.950000     31
# Dilli Rasoi                                        1.600000     31
# China Hot Pot                                      2.750000     31
# Evergreen Sweets                                   2.700000     30
# Anupam Sweets                                      2.550000     29
# The Mirch Masala                                   3.100000     29
# Sagar Dhaba                                        1.550000     29
# Mom's Kitchen                                      1.750000     28
# Amritsari Dhaba                                    3.050000     28
# Chawlas 2                                          1.500000     28
# Pizza Station                                      2.166667     28
# Organic Express                                    3.200000     27
# Rajshree                                           3.200000     27
# The China Town                                     1.700000     27
# Cake 24x7                                          1.650000     27
# Bikaner Kesarvala                                  1.600000     26
# WTF - World's Tastiest Food                        2.400000     26
# Vaishno Rasoi                                      1.300000     26
# Juice Lounge                                       1.700000     26
# Papa Buns                                          1.800000     26
# Punjabi's Veg Grill                                2.300000     25
# Niti Shake & Ice Cream Hub                         1.266667     25
# Aggarwal's Sweets Paradise                         2.800000     24
# Crust N Cakes                                      3.300000     24
# Sadda Adda                                         1.750000     24
# Food Plaza                                         1.066667     24
# Mr. Baker's                                        1.500000     23
# Pasta Hub                                          3.050000     23
# Khan Chicken Biryani                               2.900000     23
# Da Pizza Corner                                    2.260000     23
# Chinese Food                                       2.000000     21
# Garden Hut                                         2.900000     21
# Syall Kotian Da Dhaba                              1.500000     20
# Chinese Food Corner                                0.833333     20
# Super Cake Shop                                    2.050000     20
# U Like                                             1.500000     19
# Green Chilli                                       1.400000     19
# Biryani Vice                                       1.800000     19
# Mr. Momo                                           1.350000     19
# Dolce Gelato                                       0.885714     18
# Royale Bakers                                      1.400000     18
# Chai Mantra                                        1.600000     18
# Tandoori Tadka                                     1.650000     18
# The Pirates Of China Town                          1.600000     17
# Puja Sandwich House                                1.350000     17
# Hunger's Hub                                       1.550000     16
# Zaika Kathi Rolls                                  1.500000     16
# Dilli Light                                        1.300000     16
# Food Factory                                       1.500000     15
# Bakingo                                            2.850000     15
# Snack Shack                                        1.350000     15
# Dosa Plaza                                         1.600000     15
# Bikaner's                                          2.650000     15
# Chennai Express                                    1.600000     15
# Balaji Dhaba                                       1.350000     14
# Roll Corner                                        1.650000     14
# KC Bakers                                          1.600000     14
# Wild Chef House                                    1.550000     14
# Choco Kraft                                        1.600000     14
# Rolling Beans                                      2.800000     14
# Pastry Palace                                      1.600000     13
# Amar Bakery                                        1.650000     13
# Brown Town                                         1.350000     13
# Tandoori Junction                                  1.200000     13
# Lazeez Restaurant                                  1.500000     12
# Magic Masala                                       1.500000     12
# Yo! Dimsum                                         1.500000     11
# The Taste                                          3.050000     11
# Aggarwal Sweets & Restaurant                       1.350000     11
# Chauhan Hotel                                      1.450000     11
# Chai Thela                                         1.550000     11
# Ankur Family Restaurant                            2.850000     11
# Bikaner Sweets & Restaurant                        0.516667     11
# Aggarwal Bikaneri Sweets                           1.450000     11
# Yomo-Your Only Momo Outlet                         3.000000     11
# Mx Corn                                            0.775000     10
# Joost Juice Bar                                    1.066667     10
# Aggarwal Bikaner Sweets                            1.000000     10
# Grover Sweets                                      1.550000     10
# Adarsh Kulfi                                       1.500000     10
# The Chaiwalas                                      0.966667      9
# Delhi Biryani Hut                                  1.350000      9
# Shalimar Vyanjan                                   1.500000      9
# Chai Garam                                         0.725000      9
# Al Zaika                                           1.450000      9
# Mogambo Kitchen                                    1.550000      9
# The Roll Van                                       2.950000      9
# Flavors Of London                                  1.500000      8
# BonJuz                                             1.550000      8
# 6 Pack Momos                                       1.400000      8
# Delight Express                                    1.450000      8
# Rasoi                                              1.500000      7
# Pizza Hub                                          0.000000      7
# Night Food Delivery                                1.350000      7
# Jain Restaurant                                    1.500000      7
# Baba Chicken Ludhiana Wale                         1.550000      7
# Pandit Ji Ki Apni Rasoi                            1.200000      6
# Radha Swami Shudh Vaishno Dhaba                    0.000000      6
# Aggarwal Sweet Centre                              0.000000      6
# Mother's Kitchen                                   1.450000      6
# Kwality Wall's Swirl's                             0.750000      6
# Cafe Buddy's                                       1.450000      6
# Desi Tadka                                         1.500000      6
# Aggarwal Sweet & Bakers                            1.450000      5
# Kettle & Kegs                                      0.000000      5
# Madras Coffee House                                1.500000      5
# Amul Ice-Cream Parlour                             1.000000      5
# Snacks Point                                       1.450000      5
# Aggarwal Sweets Centre                             1.450000      5
# VadaPav 'n' Frankie                                1.500000      5
# ...
# True Blue                                            966.666667
# The Kitchen                                          475.000000
# Mitthu Tikki Wala                                    300.000000
# Fabulous Cake Bites                                  400.000000
# Reena Restaurant                                     375.000000
# Bharat Sweets                                        200.000000
# Haldiram Bhujiawala                                  400.000000
# Shree Durga Dosa                                     250.000000
# Vadapav Junction                                     250.000000
# Papa Veg Chinese Food                                425.000000
# Aggarwal Sweets India                                150.000000
# Hot Joint Fast Food                                  325.000000
# South Indian Cafe                                    300.000000
# Senorita's                                           425.000000
# Hangchuaa's Chinese Food Corner                      600.000000
# Bake Club                                            250.000000
# The Blue Tandoor                                     850.000000
# Garota de Ipanema                                    100.000000
# Tea Trails                                           675.000000
# Havmor Ice Cream                                     200.000000
# Mithaas Sweets                                       650.000000
# Roti Aur Boti                                        100.000000
# Kolkata Hot Kathi Roll                               200.000000
# Weird Time Food                                      600.000000
# Miam                                                 800.000000
# Ammu's South Indian Restaurant                       275.000000
# Kitchen King                                         450.000000
# Midnight Hunger                                      400.000000
# Sonya Bakery Cafe                                    350.000000
# Punjabee's Darbar                                    625.000000
# Kati Roll Cottage                                    200.000000
# Nawabi Mughlai Zaika                                 575.000000
# Zooby's Kitchen                                      800.000000
# Jack Po!tato's                                       150.000000
# The Night Owl                                        450.000000
# Urban Dhaba                                          625.000000
# Clever Fox Cafe                                      900.000000
# Gulab                                                550.000000
# Pandey Chinese Hut                                   500.000000
# Mirchievous                                          650.000000
# Gupta Ji Ka Dhaba                                    250.000000
# Cake Point                                           600.000000
# Ramesh Vaishno Dhaba                                 500.000000
# Coco Bambu                                           230.000000
# New Madras Cafe                                      266.666667
# Green Restaurant                                     325.000000
# Wah G Wah                                            450.000000
# Fresh n Refresh                                      500.000000
# New Zaika                                            650.000000
# Bhappe Di Hatti                                      325.000000
# The Cake Shop                                        200.000000
# Super Snacks                                         400.000000
# Tpot                                                 585.714286
# Metro Fast Food                                      375.000000
# South Indian Hut                                     250.000000
# EDC Mania                                            150.000000
# Aggarwal Sweet Corner                                160.000000
# Shamji Sweets                                        400.000000
# Health Buzzz                                         350.000000
# Aggarwal Sweets                                      178.571429
# Breaktym                                             400.000000
# Snack Junction                                       275.000000
# Momos House                                          350.000000
# Chao Cart                                            375.000000
# Aggarwal Sweet India                                 170.000000
# Pizza Diet                                           450.000000
# Liquid                                              1700.000000
# Mahi Rasoi                                           450.000000
# Chaap Point                                          200.000000
# Faaso's                                              600.000000
# Aapki Rasoi                                          250.000000
# Fluffles - The Fluffy Waffle Co.                     300.000000
# China Hut                                            350.000000
# Spanish Delights                                     200.000000
# Ram Chinese Food                                     400.000000
# Khalsa Veg Corner                                    300.000000
# The Belgian Fries Company                            400.000000
# Konetto Pizza                                        150.000000
# Standard Sweets                                      175.000000
# Pizza Yum                                            650.000000
# 34 Parkstreet Lane                                   225.000000
# The Chef                                             550.000000
# Dilli Rasoi                                          450.000000
# China Hot Pot                                        400.000000
# Evergreen Sweets                                     275.000000
# Anupam Sweets                                        175.000000
# The Mirch Masala                                     675.000000
# Sagar Dhaba                                          350.000000
# Mom's Kitchen                                        375.000000
# Amritsari Dhaba                                      375.000000
# Chawlas 2                                            650.000000
# Pizza Station                                        283.333333
# Organic Express                                      700.000000
# Rajshree                                             400.000000
# The China Town                                       425.000000
# Cake 24x7                                            525.000000
# Bikaner Kesarvala                                    125.000000
# WTF - World's Tastiest Food                          800.000000
# Vaishno Rasoi                                        350.000000
# Juice Lounge                                         325.000000
# Papa Buns                                            250.000000
# Punjabi's Veg Grill                                  350.000000
# Niti Shake & Ice Cream Hub                           266.666667
# Aggarwal's Sweets Paradise                           350.000000
# Crust N Cakes                                        550.000000
# Sadda Adda                                           300.000000
# Food Plaza                                           383.333333
# Mr. Baker's                                          175.000000
# Pasta Hub                                            225.000000
# Khan Chicken Biryani                                 500.000000
# Da Pizza Corner                                      600.000000
# Chinese Food                                         250.000000
# Garden Hut                                           350.000000
# Syall Kotian Da Dhaba                                550.000000
# Chinese Food Corner                                  366.666667
# Super Cake Shop                                      300.000000
# U Like                                               375.000000
# Green Chilli                                         500.000000
# Biryani Vice                                         500.000000
# Mr. Momo                                             350.000000
# Dolce Gelato                                         274.285714
# Royale Bakers                                        300.000000
# Chai Mantra                                          200.000000
# Tandoori Tadka                                       375.000000
# The Pirates Of China Town                            350.000000
# Puja Sandwich House                                  300.000000
# Hunger's Hub                                         375.000000
# Zaika Kathi Rolls                                    125.000000
# Dilli Light                                          600.000000
# Food Factory                                         400.000000
# Bakingo                                              350.000000
# Snack Shack                                          350.000000
# Dosa Plaza                                           300.000000
# Bikaner's                                            400.000000
# Chennai Express                                      300.000000
# Balaji Dhaba                                         250.000000
# Roll Corner                                          200.000000
# KC Bakers                                            350.000000
# Wild Chef House                                      500.000000
# Choco Kraft                                          300.000000
# Rolling Beans                                        225.000000
# Pastry Palace                                        425.000000
# Amar Bakery                                          375.000000
# Brown Town                                           150.000000
# Tandoori Junction                                    300.000000
# Lazeez Restaurant                                    550.000000
# Magic Masala                                         450.000000
# Yo! Dimsum                                           200.000000
# The Taste                                            375.000000
# Aggarwal Sweets & Restaurant                         250.000000
# Chauhan Hotel                                        175.000000
# Chai Thela                                           250.000000
# Ankur Family Restaurant                              400.000000
# Bikaner Sweets & Restaurant                          291.666667
# Aggarwal Bikaneri Sweets                             175.000000
# Yomo-Your Only Momo Outlet                           150.000000
# Mx Corn                                              100.000000
# Joost Juice Bar                                      300.000000
# Aggarwal Bikaner Sweets                              233.333333
# Grover Sweets                                        175.000000
# Adarsh Kulfi                                         100.000000
# The Chaiwalas                                        300.000000
# Delhi Biryani Hut                                    300.000000
# Shalimar Vyanjan                                     400.000000
# Chai Garam                                           262.500000
# Al Zaika                                             500.000000
# Mogambo Kitchen                                      275.000000
# The Roll Van                                         500.000000
# Flavors Of London                                    200.000000
# BonJuz                                               200.000000
# 6 Pack Momos                                         300.000000
# Delight Express                                      400.000000
# Rasoi                                                500.000000
# Pizza Hub                                            316.666667
# Night Food Delivery                                  500.000000
# Jain Restaurant                                      500.000000
# Baba Chicken Ludhiana Wale                           350.000000
# Pandit Ji Ki Apni Rasoi                              275.000000
# Radha Swami Shudh Vaishno Dhaba                      266.666667
# Aggarwal Sweet Centre                                150.000000
# Mother's Kitchen                                     200.000000
# Kwality Wall's Swirl's                               200.000000
# Cafe Buddy's                                         100.000000
# Desi Tadka                                           350.000000
# Aggarwal Sweet & Bakers                              150.000000
# Kettle & Kegs                                        200.000000
# Madras Coffee House                                  200.000000
# Amul Ice-Cream Parlour                               200.000000
# Snacks Point                                         125.000000
# Aggarwal Sweets Centre                               150.000000
# VadaPav 'n' Frankie                                  100.000000
# Dana Pani                                            275.000000
# Pizza Day                                            500.000000
# Meatwale.com                                         262.500000
# Fresh Meat CO                                        300.000000
# Hot & Spicy                                          350.000000
# Kesarwa Bakez                                        550.000000
# Singh Chicken                                        500.000000
# Punjabi Chicken                                      400.000000
# D Food                                               300.000000
# Biryani Bot                                          200.000000
# Flavours Kitchen                                     600.000000
# Chilli Tadka                                         350.000000
# Anand Sweets                                         125.000000
# Riyaz Biryani Corner                                 216.666667
# Lasha Chinese Food                                   275.000000
# Yadav Sweets                                         175.000000
# Golden Bakery                                        250.000000
# Kake Da Dhaba                                        375.000000
# Rasoi - The Indian Zaika                             375.000000
# OCD - Online Cake Delivery                           200.000000
# Maggi Point                                          275.000000
# Soya Bite's                                          350.000000
# Da Pizza Zone                                        550.000000
# Bikaner Sweets & Bakers                              300.000000
# Night Munchers                                       500.000000
# Chinese Hot                                          250.000000
# Ghar Ka Khana                                        125.000000
# Pizza King                                           600.000000
# Biryani Express                                      250.000000
# Special Chicken Biryani                              200.000000
# Bikaner Rasoi                                        325.000000
# Royal Spice                                          500.000000
# Essen Foods                                          600.000000
# The Square Meal                                      800.000000
# Big Biryani                                          300.000000
# Delhi Chaat Bhandar                                  100.000000
# Foodies                                              350.000000
# Garam Masala                                         350.000000
# Rajdhani Restaurant                                  300.000000
# Dev Food                                             300.000000
# Green Valley Chinese Food                            275.000000
# Bake Walkers                                         300.000000
# The Big Scoop                                        250.000000
# Chinese Fast Food                                    225.000000
# Murliwala Bakers                                     275.000000
# Whatslife.in                                         500.000000
# Bikaner Misthan Bhandar                              250.000000
# Aap Ki Khatir                                        400.000000
# Street Cafe                                          300.000000
# Jyoti Sweets                                         200.000000
# Firangi Bake                                         300.000000

# %% [markdown]
# # Level 3 - Task 1 : "Restaurant Reviews"

# %% [markdown]
# # Analyze the text reviews to identify the most common positive and negative keywords.

# %% [markdown]
# # Calculate the average length of reviews and explore if there is a relationship between review length and rating.

# %% [markdown]
# # Level 3 - Task 2 : "Votes Analysis"

# %% [markdown]
# # Identify the restaurants with the highest and lowest number of votes.

# %% [markdown]
# # Analyze if there is a correlation between the number of votes and the rating of a restaurant.

# %%
# Identify restaurants with the highest and lowest number of votes
highest_votes_restaurant = df.loc[df['Votes'].idxmax()]
lowest_votes_restaurant = df.loc[df['Votes'].idxmin()]

print("Restaurant with the Highest Number of Votes:")
print(highest_votes_restaurant[['Restaurant Name', 'Votes', 'Aggregate rating']])

print("\nRestaurant with the Lowest Number of Votes:")
print(lowest_votes_restaurant[['Restaurant Name', 'Votes', 'Aggregate rating']])

# Analyze correlation between the number of votes and restaurant rating
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Votes', y='Aggregate rating', data=df)
plt.title('Correlation between Number of Votes and Restaurant Rating')
plt.xlabel('Number of Votes')
plt.ylabel('Aggregate Rating')
plt.show()

# Calculate correlation coefficient
correlation_coefficient = df['Votes'].corr(df['Aggregate rating'])
print(f"\nCorrelation Coefficient between Votes and Rating: {correlation_coefficient}")
# Out:
# Restaurant with the Highest Number of Votes:
# Restaurant Name      Toit
# Votes               10934
# Aggregate rating      4.8
# Name: 728, dtype: object
#
# Restaurant with the Lowest Number of Votes:
# Restaurant Name     Cantinho da Gula
# Votes                              0
# Aggregate rating                 0.0
# Name: 69, dtype: object
# Correlation Coefficient between Votes and Rating: 0.3136905841954115

# %% [markdown]
# # Level 3 - Task 3 : "Price Range vs. Online Delivery and Table Booking"

# %% [markdown]
# # Analyze if there is a relationship between the price range and the availability of online delivery and table booking.

# %% [markdown]
# # Determine if higher-priced restaurants are more likely to offer these services.

# %%
# Check the unique values in the 'Price Range' column
print("Unique Price Range Values:", df['Price range'].unique())

# Replace the '$' signs in the 'Price Range' column with numeric values
df['Price range'] = df['Price range'].replace({'$': 1, '$$': 2, '$$$': 3, '$$$$': 4})

# Analyze the relationship between price range and online delivery
plt.figure(figsize=(12, 6))
sns.countplot(x='Price range', hue='Has Online delivery', data=df)
plt.title('Relationship between Price Range and Online Delivery')
plt.xlabel('Price Range')
plt.ylabel('Count')
plt.show()

# Analyze the relationship between price range and table booking
plt.figure(figsize=(12, 6))
sns.countplot(x='Price range', hue='Has Table booking', data=df)
plt.title('Relationship between Price Range and Table Booking')
plt.xlabel('Price Range')
plt.ylabel('Count')
plt.show()
# Out:
# Unique Price Range Values: [3 4 2 1]

# %%
# Replace the '$' signs in the 'Price Range' column with numeric values
df['Price range'] = df['Price range'].replace({'$': 1, '$$': 2, '$$$': 3, '$$$$': 4})

# Create subplots with two columns
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(16, 6))

# Analyze the relationship between price range and online delivery
sns.countplot(x='Price range', hue='Has Online delivery', data=df, ax=axes[0])
axes[0].set_title('Relationship between Price Range and Online Delivery')
axes[0].set_xlabel('Price Range')
axes[0].set_ylabel('Count')

# Analyze the relationship between price range and table booking
sns.countplot(x='Price range', hue='Has Table booking', data=df, ax=axes[1])
axes[1].set_title('Relationship between Price Range and Table Booking')
axes[1].set_xlabel('Price Range')
axes[1].set_ylabel('Count')

# Adjust layout
plt.tight_layout()

# Show the plots
plt.show()
